# %%
# !pip3 install streamlit
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.5/8.5 MB 19.9 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 857.8/857.8 kB 22.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 13.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 17.1 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 5.1 MB/s eta 0:00:00
# ...

# %%
import pandas as pd 
import streamlit as st

# %%
raw = pd.read_csv("/Users/florian/Documents/github/study/IoT/IoT/output.csv")

# %%
raw["date_time"] = pd.to_datetime(raw["date_time"])
raw
# Out:
#                  date_time      device_id    tmp    hum  CO2  VOC  vis   IR  \
# 0      2022-10-10 14:09:26   hka-aqm-a014  21.10  55.26  528  450  488   61
# 1      2022-10-10 14:18:26   hka-aqm-a014  22.37  51.95  526  450  528   72
# 2      2022-10-10 14:18:47   hka-aqm-a014  22.44  51.73  525  450  647  102
# 3      2022-10-10 14:19:07   hka-aqm-a014  22.50  51.63  525  450  766  130
# 4      2022-10-10 14:19:26   hka-aqm-a014  22.56  51.41  526  450  877  157
# ...                    ...            ...    ...    ...  ...  ...  ...  ...
# 824353 2023-09-26 22:50:49  hka-aqm-am308  27.38  37.58  520  950    7    3
# 824354 2023-09-26 23:05:56  hka-aqm-am308  27.36  37.58  529  948    4    2
# 824355 2023-09-26 23:21:03  hka-aqm-am308  27.35  37.61  529  966    4    0
# 824356 2023-09-26 23:36:09  hka-aqm-am308  27.34  37.65  525  944    4    0
# 824357 2023-09-26 23:51:16  hka-aqm-am308  27.33  37.65  525  951    4    0
#
# ...

# %%
raw.groupby(pd.Grouper(key= "date_time", freq= "H")).mean()
# Out:
# /var/folders/fm/5lbdpfj928d6sqhy_19cp6ww0000gn/T/ipykernel_3153/3140132881.py:1: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   raw.groupby(pd.Grouper(key= "date_time", freq= "H")).mean()
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/groupby/groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/groupby/ops.py:863, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     861     preserve_dtype = True
# --> 863 result = self._aggregate_series_pure_python(obj, func)
# ...
